# %% [markdown]
# Simple Linear Regression: y = ax + b

# %% [markdown]
# # Libraries

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()
import numpy as np

# %% [markdown]
# # Uni-dimentional Linear Regression Estimator

# %% [markdown]
# ## Data Generation

# %%
rng = np.random.RandomState(19)
x = 10*rng.rand(50)
y = 2*x-5 + rng.randn(50)
plt.scatter(x,y)

# %% [markdown]
# ## Regression

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression(fit_intercept=True) # fit_intercept=True => calculate intercept too

x_2D = x[:, np.newaxis] # LinearRegression needs x in 2D shape
model.fit(x_2D, y)
# Out:
# LinearRegression()

# %%
xfit = np.linspace(start=0, stop=10, num=1000)
yfit = model.predict(xfit[:, np.newaxis])

plt.scatter(x,y)
plt.plot(xfit, yfit, color='blue')

# %%
print(f'Model\'s Slope: {round(model.coef_[0],2)}; Model\'s Intercept: {round(model.intercept_,2)}')
# Out:
# Model's Slope: 2.0; Model's Intercept: -5.02

# %% [markdown]
# # Multi-dimentional Linear Regression Estimator

# %% [markdown]
# ## Data Generation

# %%
rng = np.random.RandomState(19)

X = 10 * rng.rand(100,3)
Y = 0.5 + np.dot(X, [1.5, -2, -1])

# %%
# fig = plt.figure()
# ax = plt.axes(projection ='3d')
# ax.plot3D(X[0], X[1], X[2])
# ax.set_title('3D Inputs')
# Out:
# Text(0.5, 0.92, '3D Inputs')

# %% [markdown]
# # Regression

# %%
model.fit(X,Y)
print(f'Model\'s Slope: {model.coef_}; Model\'s Intercept: {round(model.intercept_,2)}')
# Out:
# Model's Slope: [ 1.5 -2.  -1. ]; Model's Intercept: 0.5
